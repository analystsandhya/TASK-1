# %% [markdown]
# # **THE SPARK FOUNDATION**
# # **GRIP-JUIY21**
# **NAME-SANDHYA KANDAGAL**

# %% [markdown]
# # **TASK-1** ***Prediction Using Supervised Learning***
# # ![file-20201012-20-wfc3qi.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **1) Predict the percentage of an student based on number of study hours.**
#
#  **2) What will be the predicted score if a student studies for 9.25 hrs/day?**
#
#  **3) Dataset-http://bit.ly/w-data**

# %% [markdown]
# **IMPORTING THE REQUIRED LIBRARIES**

# %%
import pandas as pd # for data manipulation and importing dataset 
import numpy as np # for numerical computation
import seaborn as sns #for visulation 
import matplotlib.pyplot as plt

# %% [markdown]
# **READING THE DATA FROM REMOTE LINK**

# %%
url = "http://bit.ly/w-data"
DATA = pd.read_csv(url)
print("Data imported successfully")

#displaying the data
DATA
# Out:
# Data imported successfully
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %% [markdown]
# **Here we can observe that data set is small with 25 enteries,has 2 attributes hours and scores.**

# %% [markdown]
# **DISPLAYING THE DATA TYPE**

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %% [markdown]
# **SUMMARY OF DATA SET**

# %%
DATA.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
#   ### **From above can observe**
#
# *  Average study hour=5.01
# *  Average score=51.483
# *  Minimum study hour=1.1
# *  Minimum score=17
# *  Maximum study hour=9.24
# *  Maximum score=95

# %% [markdown]
#  **DATA VISUALIZATION**

# %%
# Plotting the distribution of scores
DATA.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %% [markdown]
# ### **From the above plot, we can clearly see that there is a positive linear relation between the number of hours studied and percentage of score,score increases with increase in study hours.**

# %% [markdown]
# **DATA PRE-PROCESSING**

# %%
x = DATA.iloc[:, :-1].values  
y = DATA.iloc[:, 1].values

# %% [markdown]
# **TRAINING THE MODEL BY SPLITING DATASET INTO TRAINING AND TESTING SET**

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                            test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(x_train, y_train) 

print("Training complete.")
# Out:
# Training complete.

# %% [markdown]
# **PLOTTING ALONG WITH THE REGRESSION LINE**

# %%
# Plotting the regression line
line = regressor.coef_*x+regressor.intercept_

# Plotting for the test data
plt.scatter(x,y)
plt.plot(x, line,color='yellow')
plt.title('Regression line for testing data set')
plt.ylabel('percentage score')
plt.xlabel('study hours')
plt.show()

# %% [markdown]
#  **PREDICTING THE SCORES AND TESTING THE DATA**

# %%
y_pred = regressor.predict(X_test) # Predicting the scores
print(X_test) # Testing data - In Hours
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]
#  [3.8]
#  [1.9]
#  [7.8]]

# %% [markdown]
# **LETS CHECK ACTUAL AND PREDICTED VALUES**

# %%
dataframe = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
dataframe
# Out:
#    Actual  Predicted
# 0      20  17.053665
# 1      27  33.694229
# 2      69  74.806209
# 3      30  26.842232
# 4      62  60.123359
# 5      35  39.567369
# 6      24  20.969092
# 7      86  78.721636

# %% [markdown]
# **LET US VISUALIZE THE ACTUAL AND PREDICTED VALUES BY PLOTTING**

# %%
dataframe.plot(kind='area',figsize=(8,8))
plt.show()

# %% [markdown]
# **MODEL EVALUATION USING METRICS**

# %%
from sklearn.metrics import mean_squared_error as mse
np.sqrt(mse(y_pred,y_test))
# Out:
# 4.7921912746363144

# %%
from sklearn.metrics import mean_absolute_error as mse
mae(y_pred,y_test)
# Out:
# 4.419727808027651

# %% [markdown]
# **This can also be tested with your own data**
#
# **what is the predicted score if a student studies for 9.25 hrs/day?**

# %%
hours = [[9.25]]
final_pred = regressor.predict(hours)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(final_pred[0]))
# Out:
# No of Hours = [[9.25]]
# Predicted Score = 92.91505723477056

# %% [markdown]
# #**According to our model, a student studing for 9.25 hours can score 92 percent.**
